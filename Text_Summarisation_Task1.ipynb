# %%
print("Colab is working correctly")
# Out:
# Colab is working correctly

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import string
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text = """
Artificial Intelligence (AI) is the simulation of human intelligence in machines.
These machines are programmed to think like humans and mimic their actions.
AI is used in various fields such as healthcare, education, and transportation.
It helps in automating tasks and improving efficiency.
"""

# %%
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-843854919.py in <cell line: 0>()
# ----> 1 sentences = sent_tokenize(text)
#       2 print(sentences)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#     121
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in _get_punkt_tokenizer(language)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#     106
#     107
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/punkt.py in __init__(self, lang)
#    1742     def __init__(self, lang="english"):
#    1743         PunktSentenceTokenizer.__init__(self)
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-843854919.py in <cell line: 0>()
# ----> 1 sentences = sent_tokenize(text)
#       2 print(sentences)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#     121
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in _get_punkt_tokenizer(language)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#     106
#     107
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/punkt.py in __init__(self, lang)
#    1742     def __init__(self, lang="english"):
#    1743         PunktSentenceTokenizer.__init__(self)
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['\nArtificial Intelligence (AI) is the simulation of human intelligence in machines.', 'These machines are programmed to think like humans and mimic their actions.', 'AI is used in various fields such as healthcare, education, and transportation.', 'It helps in automating tasks and improving efficiency.']

# %%
stop_words = set(stopwords.words('english'))

# %%
words = word_tokenize(text.lower())
filtered_words = [word for word in words if word not in stop_words and word not in string.punctuation]
print(filtered_words)
# Out:
# ['artificial', 'intelligence', 'ai', 'simulation', 'human', 'intelligence', 'machines', 'machines', 'programmed', 'think', 'like', 'humans', 'mimic', 'actions', 'ai', 'used', 'various', 'fields', 'healthcare', 'education', 'transportation', 'helps', 'automating', 'tasks', 'improving', 'efficiency']

# %%
word_frequencies = {}
for word in filtered_words:
    if word not in word_frequencies:
        word_frequencies[word] = 1
    else:
        word_frequencies[word] += 1

print(word_frequencies)
# Out:
# {'artificial': 1, 'intelligence': 2, 'ai': 2, 'simulation': 1, 'human': 1, 'machines': 2, 'programmed': 1, 'think': 1, 'like': 1, 'humans': 1, 'mimic': 1, 'actions': 1, 'used': 1, 'various': 1, 'fields': 1, 'healthcare': 1, 'education': 1, 'transportation': 1, 'helps': 1, 'automating': 1, 'tasks': 1, 'improving': 1, 'efficiency': 1}

# %%
sentence_scores = {}
for sent in sentences:
    for word in word_tokenize(sent.lower()):
        if word in word_frequencies:
            if sent not in sentence_scores:
                sentence_scores[sent] = word_frequencies[word]
            else:
                sentence_scores[sent] += word_frequencies[word]

print(sentence_scores)
# Out:
# {'\nArtificial Intelligence (AI) is the simulation of human intelligence in machines.': 11, 'These machines are programmed to think like humans and mimic their actions.': 8, 'AI is used in various fields such as healthcare, education, and transportation.': 8, 'It helps in automating tasks and improving efficiency.': 5}

# %%
import heapq

summary_sentences = heapq.nlargest(2, sentence_scores, key=sentence_scores.get)
print(summary_sentences)
# Out:
# ['\nArtificial Intelligence (AI) is the simulation of human intelligence in machines.', 'These machines are programmed to think like humans and mimic their actions.']

# %%
summary = " ".join(summary_sentences)
print("SUMMARY:\n", summary)
# Out:
# SUMMARY:
#
# Artificial Intelligence (AI) is the simulation of human intelligence in machines. These machines are programmed to think like humans and mimic their actions.
